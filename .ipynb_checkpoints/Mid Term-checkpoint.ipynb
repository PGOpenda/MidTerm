# %% [markdown]
# ## Company of choice and URLS of their sites
#
#    <h3>Tesla, Inc.</h3>
#
#    <ul>
#        <li>Website - https://www.tesla.com/</li>
#        <li>Twitter - https://twitter.com/Tesla</li>
#        <li>Facebook - https://web.facebook.com/TeslaMotorsCorp</li>
#        <li>Instagram - https://www.instagram.com/teslamotors/?hl=en</li>
#        <li>LinkedIn - https://www.linkedin.com/company/tesla-motors/</li>
#        <li>Youtube - https://www.youtube.com/@TeslaMotors/featured</li>
#    </ul>

# %% [markdown]
# ### Import the necessary librabries

# %%
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\piuso\anaconda3\lib\site-packages (1.8.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pillow in c:\users\piuso\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in c:\users\piuso\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\piuso\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\piuso\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\piuso\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\piuso\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\piuso\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\piuso\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\piuso\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\piuso\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter
from wordcloud import WordCloud, STOPWORDS
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('porter_test')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\piuso\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\piuso\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package porter_test to
# [nltk_data]     C:\Users\piuso\AppData\Roaming\nltk_data...
# [nltk_data]   Package porter_test is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\piuso\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
scraper = sntwitter.TwitterSearchScraper('from:amazon')

tweets = []

n_tweets = 20000

for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets): 
    
    data = [
        tweet.rawContent
    ]
    
    tweets.append(data)
    
    if i > n_tweets:
        break
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]

# %% [markdown]
# ### Load your social media data

# %%
# Display the sample data in our data frame
tweet_df = pd.DataFrame(tweets,columns=["tweets"])

tweet_df.to_csv("amazondata.csv", index=False)

tweet_df.head(10)
# Out:
#                                               tweets
# 0                                  @joshdrrn 🏃 🏃 💨 💨
# 1  @aaronwerner830 Aww, thanks so much for the ki...
# 2  @Majickmedicine1 Aww, thanks for the kind word...
# 3  @SimplyAshley92 We're sorry to hear that we've...
# 4                            https://t.co/n3j5CRcVel
# 5  An Epic Adventure Awaits: Prime members can at...
# 6  @SwissFaryGodBro She sounds like so much fun!!...
# 7       @MonkeyKingApe Happy (early) Birthday!!! 🎂 🎂
# 8  @NewMe7oCity This is a pretty 🔥 🔥 haul! We lov...
# 9  @MkayYOUBASTARD HAPPY BIRTHDAY!! 🎂 🎁 🎈 🎉 What ...

# %% [markdown]
# ### Clean the text data
# <ul>
#     <li>Remove URLS</li>
# </ul>

# %%
#Remove the urls
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub('', text)

tweet_df['tweets'] = tweet_df['tweets'].apply(remove_urls)

print(tweet_df['tweets'].sample(10))
# Out:
# 15560    @KLeoPullin Thanks for sharing this! It's grea...
# 8471     @bprinceeex3 Just pudding it out there, if you...
# 17214    @lukewlcx We're incredibly happy to hear you'r...
# 928      @QuaySlim WE LOVE THAT FOR YOU! 😍 What genre d...
# 19905    @JohnWBeaton You got 99 problems, but a snitch...
# 11511    @MzLocQueen Picture perfect deliveries is the ...
# 2209      @CoastalPaleo WOO-HOO! Happy delivery dance! 💃 👋
# 9947     @jennabee25 You and Sputnik are very welcome! ...
# 7645     @jepworker77 We're really happy you're enjoyin...
# 9402     @WriterRen Seems it's in your *nature* to spre...
# Name: tweets, dtype: object

# %% [markdown]
# <ul>
#     <li>Remove Special Characters</li>
# </ul>

# %%
#Remove special characters
def remove_special_characters(text):
    pattern = r'[^a-zA-Z0-9\s]' # keep only alphanumeric and whitespace characters
    text = re.sub(pattern, '', text)
    return text

tweet_df['tweets'] = tweet_df['tweets'].apply(remove_special_characters)

print(tweet_df['tweets'].sample(10))
# Out:
# 3552     beingsalman94 Wed like to help you Could you e...
# 13186                                         Octane10820
# 13029    deha Last time we exercised our legs started m...
# 11814    destinyrmakeup That will be more like tattwelv...
# 2067     Metabad Thank you so much   We appreciate the ...
# 12627    sweetk01 We wanted to take the thyme to let yo...
# 9627     BeeeNelson  Well arent you just sweet as PIE Y...
# 18284                                           queenery1
# 4070     tasleem26877841 We get your concern regarding ...
# 18060    XXabhi Were glad to hear youre loving your Ech...
# Name: tweets, dtype: object

# %% [markdown]
# <ul>
#     <li>Convert text to lower case</li>
# </ul>

# %%
tweet_df['tweets'] = tweet_df['tweets'].str.lower()

print(tweet_df['tweets'].sample(10))
# Out:
# 14445    realboblawler apologies for the delay we alway...
# 2619     stridefully we totally know what you mean  spe...
# 6073      read like the stars with celebrity picks from...
# 4780     lippityliplip were happy to hear you found you...
# 9321     slylars1 were so sorry to hear about this wed ...
# 9049     banana722418 aww your husband sounds so sweet ...
# 5937     1200microgram hello thank you for reaching out...
# 3598     femennenly we dont see the purroblem  when the...
# 586                       fitzandchips  we aim to deliver
# 2335     angietweetz ohh my goodness  they sound adorab...
# Name: tweets, dtype: object

# %% [markdown]
# <ul>
#     <li>Tokenize the text data</li>
# </ul>

# %%
# Tokenize the text data
# Resulting tokens are stored in a new column called tokens
tweet_df['tokens'] = tweet_df['tweets'].apply(nltk.word_tokenize)

tweet_df.head(10)
# Out:
#                                               tweets  \
# 0                                       joshdrrn
# 1  aaronwerner830 aww thanks so much for the kind...
# 2  majickmedicine1 aww thanks for the kind words ...
# 3  simplyashley92 were sorry to hear that weve di...
# 4
# 5  an epic adventure awaits prime members can att...
# 6  swissfarygodbro she sounds like so much fun  w...
# 7               monkeykingape happy early birthday
# 8  newme7ocity this is a pretty   haul we love to...
# 9  mkayyoubastard happy birthday     what awesome...
#
#                                               tokens
# 0                                         [joshdrrn]
# 1  [aaronwerner830, aww, thanks, so, much, for, t...
# 2  [majickmedicine1, aww, thanks, for, the, kind,...
# 3  [simplyashley92, were, sorry, to, hear, that, ...
# 4                                                 []
# 5  [an, epic, adventure, awaits, prime, members, ...
# 6  [swissfarygodbro, she, sounds, like, so, much,...
# 7            [monkeykingape, happy, early, birthday]
# 8  [newme7ocity, this, is, a, pretty, haul, we, l...
# 9  [mkayyoubastard, happy, birthday, what, awesom...

# %% [markdown]
# <ul>
#     <li>Remove stopwords</li>
# </ul>

# %%
# Remove stopwords
from nltk.corpus import stopwords

def remove_stopwords(tokens):
    stopwords_list = stopwords.words('english')
    filtered_tokens = [token for token in tokens if token.lower() not in stopwords_list]
    return filtered_tokens

tweet_df['tokens'] = tweet_df['tokens'].apply(remove_stopwords)

print(tweet_df['tokens'].sample(10))
# Out:
# 14338    [djdevo79, glad, cleo, enjoying, package, hope...
# 6826     [unicornmomster, month, love, love, delivering...
# 6217     [apinkerton135, mom, special, deserves, everyt...
# 11045    [cryptomib, absotoothly, thrilled, know, youre...
# 7167     [vivekpr91250874, understand, concern, regardi...
# 14919    [frose90, awesome, interests, wed, love, send,...
# 13195                       [realsamgabriel, best, summon]
# 3204     [jayemholla, youre, welcome, love, deliverings...
# 18600    [katiebaker023, youre, welcome, merry, christmas]
# 3598     [femennenly, dont, see, purroblem, two, meowgi...
# Name: tokens, dtype: object

# %% [markdown]
# ### Stem and display a sample of the stemmed data

# %%
# Stem the data
from nltk.stem import PorterStemmer

def stem_tokens(tokens):
    porter = PorterStemmer()
    stemmed_tokens = [porter.stem(token) for token in tokens]
    return stemmed_tokens

tweet_df['stemmed_tokens'] = tweet_df['tokens'].apply(stem_tokens)

print(tweet_df['stemmed_tokens'].sample(10))

tweet_df.head(10)
# Out:
# 17384                 [swiftiesabrina, prep, occas, right]
# 5091          [theothermariah, sayw, love, deliveringsmil]
# 13025    [melissagingerc, look, like, your, set, bit, l...
# 10830    [gideonhodg, actual, hear, lot, that, decid, p...
# 2466     [alseptjam, awwwww, littl, cuti, name, look, l...
# 9492     [whoseparadis, kind, word, made, day, thank, s...
# 13969    [whether, ship, deliveri, return, pickup, weve...
# 6283     [get, prime, shop, benefit, even, arent, shop,...
# 3446                           [reblfleurle, that, fastin]
# 16484                  [baybygiiiirl, happi, deliv, smile]
# Name: stemmed_tokens, dtype: object
#                                               tweets  \
# 0                                       joshdrrn
# 1  aaronwerner830 aww thanks so much for the kind...
# 2  majickmedicine1 aww thanks for the kind words ...
# 3  simplyashley92 were sorry to hear that weve di...
# 4
# 5  an epic adventure awaits prime members can att...
# 6  swissfarygodbro she sounds like so much fun  w...
# 7               monkeykingape happy early birthday
# 8  newme7ocity this is a pretty   haul we love to...
# 9  mkayyoubastard happy birthday     what awesome...
#
#                                               tokens  \
# 0                                         [joshdrrn]
# 1   [aaronwerner830, aww, thanks, much, kind, words]
# 2        [majickmedicine1, aww, thanks, kind, words]
# 3  [simplyashley92, sorry, hear, weve, disappoint...
# 4                                                 []
# 5  [epic, adventure, awaits, prime, members, atte...
# 6  [swissfarygodbro, sounds, like, much, fun, wed...
# 7            [monkeykingape, happy, early, birthday]
# 8             [newme7ocity, pretty, haul, love, see]
# 9  [mkayyoubastard, happy, birthday, awesome, thi...
#
#                                       stemmed_tokens
# 0                                         [joshdrrn]
# 1     [aaronwerner830, aww, thank, much, kind, word]
# 2          [majickmedicine1, aww, thank, kind, word]
# 3  [simplyashley92, sorri, hear, weve, disappoint...
# 4                                                 []
# 5  [epic, adventur, await, prime, member, attend,...
# 6  [swissfarygodbro, sound, like, much, fun, wed,...
# 7             [monkeykingap, happi, earli, birthday]
# 8                [newme7oc, pretti, haul, love, see]
# 9  [mkayyoubastard, happi, birthday, awesom, thin...

# %% [markdown]
# ### Lemmatize and display a sample of the lemmatized data

# %%
# Lemmatize the data
from nltk.stem import WordNetLemmatizer

def lemmatize_tokens(stemmed_tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in stemmed_tokens]
    return lemmatized_tokens

tweet_df['lemmatized_tokens'] = tweet_df['stemmed_tokens'].apply(lemmatize_tokens)

print(tweet_df['lemmatized_tokens'].sample(10))

tweet_df.head(10)
# Out:
# 3046     [natsqueak, let, get, control, worldkindnessda...
# 6662                          [coopy44, aint, shame, game]
# 17363    [leannewel, fred, look, like, take, best, cat,...
# 19108    [hellomag, great, black, friday, wonder, happe...
# 7779     [thestoryofakat, cours, could, pas, glare, lik...
# 1930     [daisymenjivar1, deliveri, sound, like, wonder...
# 7849     [kamivirat, thank, reach, amazon, prime, custo...
# 10893    [what, goto, primevideo, stream, genr, check, ...
# 18664    [grantliffmann, thank, share, grant, that, paw...
# 3829     [neilpirie7, understand, your, say, plea, use,...
# Name: lemmatized_tokens, dtype: object
#                                               tweets  \
# 0                                       joshdrrn
# 1  aaronwerner830 aww thanks so much for the kind...
# 2  majickmedicine1 aww thanks for the kind words ...
# 3  simplyashley92 were sorry to hear that weve di...
# 4
# 5  an epic adventure awaits prime members can att...
# 6  swissfarygodbro she sounds like so much fun  w...
# 7               monkeykingape happy early birthday
# 8  newme7ocity this is a pretty   haul we love to...
# 9  mkayyoubastard happy birthday     what awesome...
#
#                                               tokens  \
# 0                                         [joshdrrn]
# 1   [aaronwerner830, aww, thanks, much, kind, words]
# 2        [majickmedicine1, aww, thanks, kind, words]
# 3  [simplyashley92, sorry, hear, weve, disappoint...
# 4                                                 []
# 5  [epic, adventure, awaits, prime, members, atte...
# 6  [swissfarygodbro, sounds, like, much, fun, wed...
# 7            [monkeykingape, happy, early, birthday]
# 8             [newme7ocity, pretty, haul, love, see]
# 9  [mkayyoubastard, happy, birthday, awesome, thi...
#
#                                       stemmed_tokens  \
# 0                                         [joshdrrn]
# 1     [aaronwerner830, aww, thank, much, kind, word]
# 2          [majickmedicine1, aww, thank, kind, word]
# 3  [simplyashley92, sorri, hear, weve, disappoint...
# 4                                                 []
# 5  [epic, adventur, await, prime, member, attend,...
# 6  [swissfarygodbro, sound, like, much, fun, wed,...
# 7             [monkeykingap, happi, earli, birthday]
# 8                [newme7oc, pretti, haul, love, see]
# 9  [mkayyoubastard, happi, birthday, awesom, thin...
#
#                                    lemmatized_tokens
# 0                                         [joshdrrn]
# 1     [aaronwerner830, aww, thank, much, kind, word]
# 2          [majickmedicine1, aww, thank, kind, word]
# 3  [simplyashley92, sorri, hear, weve, disappoint...
# 4                                                 []
# 5  [epic, adventur, await, prime, member, attend,...
# 6  [swissfarygodbro, sound, like, much, fun, wed,...
# 7             [monkeykingap, happi, earli, birthday]
# 8                [newme7oc, pretti, haul, love, see]
# 9  [mkayyoubastard, happi, birthday, awesom, thin...

# %% [markdown]
# ### Use word cloud to visualize the data from the above step

# %%
# Combine all lemmatized tokens into a single list
all_tokens = []
for row in tweet_df['lemmatized_tokens']:
    all_tokens += row

# Join the tokens into a single string separated by spaces
text = ' '.join(all_tokens)

# Create a WordCloud object and generate the word cloud
wordcloud = WordCloud(width=800, height=800, background_color='white', stopwords=STOPWORDS, min_font_size=10).generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ### Save the cleaned data to a new CSV file

# %%
data.to_csv('cleaned_data.csv', index=False)
